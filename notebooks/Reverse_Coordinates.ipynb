# %%
import os
import pandas as pd
from IPython.display import display
import numpy as np
import googlemaps
from datetime import datetime

# %%
GNR = pd.read_csv("../data/curated/GNR.csv",low_memory=False)

# %%
def reverse_coord(gmaps,coordinates):
    # Look up an address with reverse geocoding
    reverse_geocode_result = gmaps.reverse_geocode((coordinates))
    return reverse_geocode_result[0]["formatted_address"]
    

def generate_suburb_postcode(df):
    gmaps = googlemaps.Client(key='AIzaSyAwGu0E8STeETxFXmrL0UjyeF7mFRAn_5k')
    df["coordinates"] = df["LATITUDE"].astype(str) + ", " + df["LONGITUDE"].astype(str)
    df["Reverse_Coord"]= df["coordinates"].apply(gmaps,reverse_coord)
    return df

# %%
clean_GNR = generate_suburb_postcode(clean_GNR)

# %%
external = pd.read_csv("../data/curated/external.csv",low_memory=False)

# %%
external
# Out:
#       postcode        locality state            LGA   SA3_NAME_2016  \
# 0         3000       MELBOURNE   VIC      Melbourne  Melbourne City
# 1         3001       MELBOURNE   VIC  Moonee Valley  Melbourne City
# 2         3002  EAST MELBOURNE   VIC          Yarra  Melbourne City
# 3         3003  WEST MELBOURNE   VIC      Melbourne  Melbourne City
# 4         3004       MELBOURNE   VIC          Yarra  Melbourne City
# ...        ...             ...   ...            ...             ...
# 3529      8111       MELBOURNE   VIC          Yarra  Melbourne City
# 3530      8120       MELBOURNE   VIC          Yarra  Melbourne City
# 3531      8205       MELBOURNE   VIC          Yarra  Melbourne City
# 3532      8785       DANDENONG   VIC         Monash       Dandenong
# 3533      9999      NORTH POLE   VIC          Yarra  Melbourne City
#
#          SA2_Code        SA2_Name  2001_population  2002_population  \
# 0     206041122.0       Melbourne              NaN              NaN
# ...

# %%
gmaps = googlemaps.Client(key='AIzaSyAwGu0E8STeETxFXmrL0UjyeF7mFRAn_5k')

# Look up an address with reverse geocoding
reverse_geocode_result = gmaps.reverse_geocode((-37.798, 144.9613))

# %%
reverse_geocode_result[0]["formatted_address"]
# Out:
# 'East Wing - Old Quad The University of, Parkville VIC 3010, Australia'

# %%
gmaps.reverse_geocode((-37.8141725, 144.9740049))[0]["formatted_address"]

# %%
display(GNR.head(100))
# Out:
#     PLACE_ID                PLACE_NAME       FEATURE  LONGITUDE  LATITUDE  \
# 0        338     BALLARAT FIRE STATION  FIRE STATION   143.8686   -37.563
# 1       1257    BUNINYONG FIRE STATION  FIRE STATION   143.8851   -37.650
# 2       3728     INVERMAY FIRE STATION  FIRE STATION   143.8724   -37.521
# 3       5179  MINERS REST FIRE STATION  FIRE STATION   143.7989   -37.479
# 4       8520    WENDOUREE FIRE STATION  FIRE STATION   143.8197   -37.535
# ..       ...                       ...           ...        ...       ...
# 95      3803     JANCOURT FIRE STATION  FIRE STATION   143.1356   -38.383
# 96      4460      LARPENT FIRE STATION  FIRE STATION   143.4944   -38.343
# 97      4482  LAVERS HILL FIRE STATION  FIRE STATION   143.3905   -38.678
# 98      4482        OTWAY FIRE STATION  FIRE STATION   143.3905   -38.678
# 99      4602      LISMORE FIRE STATION  FIRE STATION   143.3379   -37.953
#
#                                          geometry
# ...

# %%
GNR["FEATURE"].unique()
# Out:
# array(['FIRE STATION', 'SECONDARY SCHOOL', 'PRIMARY AND SECONDARY SCHOOL',
#        'PRIMARY SCHOOL', 'SHOPPING CENTRE', 'PARK', 'KINDERGARTEN',
#        'POST OFFICE', 'SPECIAL SCHOOL', 'CHILD CARE', 'RAILWAY', 'BAR',
#        'LOCAL GOVERNMENT AREA', 'SPORTS COMPLEX', 'EDUCATION COMPLEX',
#        'CEMETERY', 'LIBRARY', 'UNIVERSITY', 'GENERAL HOSPITAL',
#        'POLICE STATION', 'FURTHER EDUCATION', 'PLAYGROUND', 'PLANTATION',
#        'WINERY', 'FARM', 'VINEYARD', 'TENNIS COURT', 'BOWLING GREEN',
#        'BAY', 'PIER', 'SWIMMING POOL', 'ART GALLERY', 'HARBOUR',
#        'COMMUNITY HEALTH CENTRE', 'MATERNAL AND CHILD HEALTH CENTRE',
#        'MARKET', 'PRISON', 'BOTANIC GARDENS', 'SPECIALISED HOSPITAL',
#        'BANK', 'TERTIARY INSTITUTION', 'AGED CARE', 'SURFING SPOT',
#        'AMBULANCE STATION', 'COAST', 'ARBORETUM', 'VELODROME',
#        'GOLF COURSE', 'EQUESTRIAN CENTRE', 'LIGHT RAIL STATION',
#        'HELIPORT', 'AIRPORT', 'FIRING RANGE', 'IRON ORE PROCESSOR',
# ...

# %%
GNR[GNR["FEATURE"] == 'UNIVERSITY']
# Out:
#        PLACE_ID                                         PLACE_NAME  \
# 12402    122377        VICTORIA UNIVERSITY - FOOTSCRAY PARK CAMPUS
# 12403    122387   VICTORIA UNIVERSITY - FOOTSCRAY NICHOLSON CAMPUS
# 12404    119049       UNIVERSITY OF BALLARAT -SMB CHILDRENS CENTRE
# 12405    117856  VICTORIA UNIVERSITY CHILDRENS CENTRE -FOOTSCRA...
# 12406    117857  VICTORIA UNIVERSITY CHILDRENS CENTRE -FOOTSCRA...
# 12407    117858      VICTORIA UNIVERSITY CHILDRENS CENTRE -NEWPORT
# 12408    117859  VICTORIA UNIVERSITY CHILDRENS CENTRE -WERRIBEE...
# 12409     20803                               MELBOURNE UNIVERSITY
# 12410     28426                             UNIVERSITY HIGH SCHOOL
# 12411     21267                                  MONASH UNIVERSITY
# 12412     14083                                  DEAKIN UNIVERSITY
# 12413     28427                                   UNIVERSITY LODGE
# 12414     19130                                LA TROBE UNIVERSITY
# ...
